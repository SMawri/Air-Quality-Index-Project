# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
### Generalised Function to get data from every excel
def avg_data():
    temp_i=0
    average=[]
    for year in range(2013,2019):
        for rows in pd.read_csv('C:/Users/sandeep.mawri/Documents/Krish/AQI-Project-master/AQI-Project-master/Data/AQI/aqi{}.csv'.format(year),chunksize=24):
            add_var=0
            avg=0.0
            data=[]
            df=pd.DataFrame(data=rows)
            for index,row in df.iterrows():
                data.append(row['PM2.5'])
                for i in data:
                    if type(i) is float or type(i) is int:
                        add_var=add_var+i
                    elif type(i) is str:
                        if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                            temp=float(i)
                            add_var=add_var+temp
            avg=add_var/24
            temp_i=temp_i+1
            
            average.append(avg)
    return average

# %%
if __name__=="__main__":
    lst=avg_data()
    plt.plot(lst,label="PM2.5 data")
    plt.xlabel('Day')
    plt.ylabel('PM 2.5')
    plt.legend(loc='upper right')
    plt.show()

# %%
avg_data()
# Out:
# [3154.937500000002,
#  2543.9791666666656,
#  1923.8125000000018,
#  2024.5875000000012,
#  0.0,
#  12.379166666666668,
#  1130.070833333334,
#  2962.3624999999993,
#  2667.9750000000017,
#  2060.3125000000005,
#  1501.433333333334,
#  2737.61666666667,
#  3245.2374999999975,
#  3436.2624999999985,
#  3966.450000000003,
#  3184.6499999999983,
#  3372.816666666666,
#  505.2583333333337,
#  1335.762499999999,
#  1395.2749999999994,
#  1432.5499999999993,
#  2151.533333333334,
#  3336.4125000000017,
#  3054.0583333333348,
#  2499.920833333335,
#  1854.0458333333336,
#  1940.5125000000014,
#  2124.716666666668,
#  3202.8208333333337,
#  3064.162499999998,
#  4220.87916666667,
#  4807.837499999997,
#  4022.7458333333307,
#  2738.775000000003,
#  2460.3333333333326,
#  1027.4999999999998,
#  718.125,
#  629.25,
#  1208.0833333333333,
#  1118.0833333333333,
#  2733.25,
#  2710.375,
#  1874.5833333333333,
#  1741.7083333333333,
#  1688.4166666666667,
#  1815.5,
#  0.0,
#  0.0,
#  0.0,
# ...

# %%
def avg_data_2013():
    temp_i=0
    average=[]
    for rows in pd.read_csv('C:/Users/sandeep.mawri/Documents/Krish/AQI-Project-master/AQI-Project-master/Data/AQI/aqi2013.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    
def avg_data_2014():
    temp_i=0
    average=[]
    for rows in pd.read_csv('C:/Users/sandeep.mawri/Documents/Krish/AQI-Project-master/AQI-Project-master/Data/AQI/aqi2014.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    
def avg_data_2015():
    temp_i=0
    average=[]
    for rows in pd.read_csv('C:/Users/sandeep.mawri/Documents/Krish/AQI-Project-master/AQI-Project-master/Data/AQI/aqi2015.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average

    
def avg_data_2016():
    temp_i=0
    average=[]
    for rows in pd.read_csv('C:/Users/sandeep.mawri/Documents/Krish/AQI-Project-master/AQI-Project-master/Data/AQI/aqi2016.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    
def avg_data_2017():
    temp_i=0
    average=[]
    for rows in pd.read_csv('C:/Users/sandeep.mawri/Documents/Krish/AQI-Project-master/AQI-Project-master/Data/AQI/aqi2017.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    
def avg_data_2018():
    temp_i=0
    average=[]
    for rows in pd.read_csv('C:/Users/sandeep.mawri/Documents/Krish/AQI-Project-master/AQI-Project-master/Data/AQI/aqi2018.csv',chunksize=24):
        add_var=0
        avg=0.0
        data=[]
        df=pd.DataFrame(data=rows)
        for index,row in df.iterrows():
            data.append(row['PM2.5'])
        for i in data:
            if type(i) is float or type(i) is int:
                add_var=add_var+i
            elif type(i) is str:
                if i!='NoData' and i!='PwrFail' and i!='---' and i!='InVld':
                    temp=float(i)
                    add_var=add_var+temp
        avg=add_var/24
        temp_i=temp_i+1
        
        average.append(avg)
    return average
    

if __name__=="__main__":
    lst2013=avg_data_2013()
    lst2014=avg_data_2014()
    lst2015=avg_data_2015()
    lst2016=avg_data_2016()
    lst2017=avg_data_2017()
    lst2018=avg_data_2018()
    
    plt.plot(range(0,365),lst2013,label="2013 data")
    plt.plot(range(0,364),lst2014,label="2014 data")
    plt.plot(range(0,365),lst2015,label="2015 data")
    plt.plot(range(0,365),lst2016,label="2016 data")
    plt.xlabel('Day')
    plt.ylabel('PM 2.5')
    plt.legend(loc='upper right')
    plt.show()
